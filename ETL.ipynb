# %%
import pandas as pd

# %%
df = pd.read_csv("data_temp/datos-donaciones.csv")

# %%
df.head(3)
# Out:
#    Unnamed: 0                                NOMBRE.DEL.PROYECTO  \
# 0     4986651          Inserción a la Educación Técnica Superior
# 1     5280931  Operacion de Programas Terapeuticos Residencia...
# 2     5308541  Operación de Programas Terapéuticos Ambulatori...
#
#                       DONATARIO                         DONANTE       RUT  \
# 0  FUNDACION EDUCACIONAL SUMATE      HERNAN ARTURO GARFIAS ARZE  71644073
# 1        Fundación (Paréntesis)  MARION ERICA FEDDERSEN WELKNER  71652912
# 2        Fundación (Paréntesis)     JUAN BAUTISTA ORELLANA MORA  71653277
#
#    Dígito  MONTO.FONDO.MIXTO  MONTO.INSTITUCIÓN  monto.total.donacion.num  \
# 0       3                NaN              10000                     10000
# 1       2                NaN              20000                     20000
# 2       7                NaN               6000                      6000
#
#     Año  Mes  Día
# 0  2015    6   30
# 1  2015    6   30
# 2  2015    6   30

# %%
df = df.rename(columns={"Unnamed: 0":"codigo", "NOMBRE.DEL.PROYECTO":"nombre_del_proyecto", "DONATARIO":"donatario", "DONANTE":"donante", "RUT":"rut", "Dígito":"digito", "MONTO.FONDO.MIXTO":"monto_fondo_mixto", "MONTO.INSTITUCIÓN":"monto_institucion", "monto.total.donacion.num":"monto_total_donacion_num", "Año":"año", "Mes":"mes", "Día":"dia"} )
# df=df.rename(columns={"Unnamed: 0":"donation_id", "NOMBRE.DEL.PROYECTO":"project_name", "DONATARIO":"donor", "DONANTE":"donator", "RUT":"id", "Dígito":"digit", "MONTO.FONDO.MIXTO":"mixed_fond_amount", "MONTO.INSTITUCIÓN":"institution_amount", "monto.total.donacion.num":"total_donation_amount_num", "Año":"year", "Mes":"month", "Día":"day"} )

# %%
df.head(3)
# Out:
#     codigo                                nombre_del_proyecto  \
# 0  4986651          Inserción a la Educación Técnica Superior
# 1  5280931  Operacion de Programas Terapeuticos Residencia...
# 2  5308541  Operación de Programas Terapéuticos Ambulatori...
#
#                       donatario                         donante       rut  \
# 0  FUNDACION EDUCACIONAL SUMATE      HERNAN ARTURO GARFIAS ARZE  71644073
# 1        Fundación (Paréntesis)  MARION ERICA FEDDERSEN WELKNER  71652912
# 2        Fundación (Paréntesis)     JUAN BAUTISTA ORELLANA MORA  71653277
#
#    digito  monto_fondo_mixto  monto_institucion  monto_total_donacion_num  \
# 0       3                NaN              10000                     10000
# 1       2                NaN              20000                     20000
# 2       7                NaN               6000                      6000
#
#     año  mes  dia
# 0  2015    6   30
# 1  2015    6   30
# 2  2015    6   30

# %%
df["donatario"] = df["donatario"].str.upper()

# %%
df.head(3)
# Out:
#     codigo                                nombre_del_proyecto  \
# 0  4986651          Inserción a la Educación Técnica Superior
# 1  5280931  Operacion de Programas Terapeuticos Residencia...
# 2  5308541  Operación de Programas Terapéuticos Ambulatori...
#
#                       donatario                         donante       rut  \
# 0  FUNDACION EDUCACIONAL SUMATE      HERNAN ARTURO GARFIAS ARZE  71644073
# 1        FUNDACIÓN (PARÉNTESIS)  MARION ERICA FEDDERSEN WELKNER  71652912
# 2        FUNDACIÓN (PARÉNTESIS)     JUAN BAUTISTA ORELLANA MORA  71653277
#
#    digito  monto_fondo_mixto  monto_institucion  monto_total_donacion_num  \
# 0       3                NaN              10000                     10000
# 1       2                NaN              20000                     20000
# 2       7                NaN               6000                      6000
#
#     año  mes  dia
# 0  2015    6   30
# 1  2015    6   30
# 2  2015    6   30

# %%
df["mes"] = df["mes"].astype(str).str.zfill(2)

# %%
df["dia"] = df["dia"].astype(str).str.zfill(2)

# %%
df["fecha"] = df["año"].astype(str) + "/" + df["mes"].astype(str) +"/" + df["dia"].astype(str)

# %%
df.head(3)
# Out:
#     codigo                                nombre_del_proyecto  \
# 0  4986651          Inserción a la Educación Técnica Superior
# 1  5280931  Operacion de Programas Terapeuticos Residencia...
# 2  5308541  Operación de Programas Terapéuticos Ambulatori...
#
#                       donatario                         donante       rut  \
# 0  FUNDACION EDUCACIONAL SUMATE      HERNAN ARTURO GARFIAS ARZE  71644073
# 1        FUNDACIÓN (PARÉNTESIS)  MARION ERICA FEDDERSEN WELKNER  71652912
# 2        FUNDACIÓN (PARÉNTESIS)     JUAN BAUTISTA ORELLANA MORA  71653277
#
#    digito  monto_fondo_mixto  monto_institucion  monto_total_donacion_num  \
# 0       3                NaN              10000                     10000
# 1       2                NaN              20000                     20000
# 2       7                NaN               6000                      6000
#
#     año mes dia       fecha
# 0  2015  06  30  2015/06/30
# 1  2015  06  30  2015/06/30
# 2  2015  06  30  2015/06/30

# %%
df["rut"] = df["rut"].astype("str").str[0:7]

# %%
df.drop(columns={"año", "mes", "dia"})
# Out:
#        codigo                                nombre_del_proyecto  \
# 0     4986651          Inserción a la Educación Técnica Superior
# 1     5280931  Operacion de Programas Terapeuticos Residencia...
# 2     5308541  Operación de Programas Terapéuticos Ambulatori...
# 3     4989901  Derecho a la Educacion para Todos: Mejoramient...
# 4     2094102  Atención Técnica Directa al Adulto Mayor Insti...
# 5     5307051  Operación de Programas Terapéuticos Ambulatori...
# 6     4983391          Inserción a la Educación Técnica Superior
# 7     4975841        Programas Prevención a la Deserción Escolar
# 8     4987881          Inserción a la Educación Técnica Superior
# 9     4987612          Inserción a la Educación Técnica Superior
# 10    5288751  Operacion de Programas Terapeuticos Residencia...
# 11    5283631  Operacion de Programas Terapeuticos Residencia...
# 12    5290761  Operacion de Programas Terapeuticos Residencia...
# ...

# %%
df["nombre_del_proyecto"] = df["nombre_del_proyecto"].str.upper()

# %%
df["donante"] = df["donante"].str.upper()

# %%
df["monto_fondo_mixto"] = df["monto_fondo_mixto"].fillna(0)

# %%
df
# Out:
#        codigo                                nombre_del_proyecto  \
# 0     4986651          INSERCIÓN A LA EDUCACIÓN TÉCNICA SUPERIOR
# 1     5280931  OPERACION DE PROGRAMAS TERAPEUTICOS RESIDENCIA...
# 2     5308541  OPERACIÓN DE PROGRAMAS TERAPÉUTICOS AMBULATORI...
# 3     4989901  DERECHO A LA EDUCACION PARA TODOS: MEJORAMIENT...
# 4     2094102  ATENCIÓN TÉCNICA DIRECTA AL ADULTO MAYOR INSTI...
# 5     5307051  OPERACIÓN DE PROGRAMAS TERAPÉUTICOS AMBULATORI...
# 6     4983391          INSERCIÓN A LA EDUCACIÓN TÉCNICA SUPERIOR
# 7     4975841        PROGRAMAS PREVENCIÓN A LA DESERCIÓN ESCOLAR
# 8     4987881          INSERCIÓN A LA EDUCACIÓN TÉCNICA SUPERIOR
# 9     4987612          INSERCIÓN A LA EDUCACIÓN TÉCNICA SUPERIOR
# 10    5288751  OPERACION DE PROGRAMAS TERAPEUTICOS RESIDENCIA...
# 11    5283631  OPERACION DE PROGRAMAS TERAPEUTICOS RESIDENCIA...
# 12    5290761  OPERACION DE PROGRAMAS TERAPEUTICOS RESIDENCIA...
# ...

# %%
df.drop(columns={"año", "mes", "dia"})
# Out:
#        codigo                                nombre_del_proyecto  \
# 0     4986651          INSERCIÓN A LA EDUCACIÓN TÉCNICA SUPERIOR
# 1     5280931  OPERACION DE PROGRAMAS TERAPEUTICOS RESIDENCIA...
# 2     5308541  OPERACIÓN DE PROGRAMAS TERAPÉUTICOS AMBULATORI...
# 3     4989901  DERECHO A LA EDUCACION PARA TODOS: MEJORAMIENT...
# 4     2094102  ATENCIÓN TÉCNICA DIRECTA AL ADULTO MAYOR INSTI...
# 5     5307051  OPERACIÓN DE PROGRAMAS TERAPÉUTICOS AMBULATORI...
# 6     4983391          INSERCIÓN A LA EDUCACIÓN TÉCNICA SUPERIOR
# 7     4975841        PROGRAMAS PREVENCIÓN A LA DESERCIÓN ESCOLAR
# 8     4987881          INSERCIÓN A LA EDUCACIÓN TÉCNICA SUPERIOR
# 9     4987612          INSERCIÓN A LA EDUCACIÓN TÉCNICA SUPERIOR
# 10    5288751  OPERACION DE PROGRAMAS TERAPEUTICOS RESIDENCIA...
# 11    5283631  OPERACION DE PROGRAMAS TERAPEUTICOS RESIDENCIA...
# 12    5290761  OPERACION DE PROGRAMAS TERAPEUTICOS RESIDENCIA...
# ...

# %%
df["nombre_del_proyecto"] = df["nombre_del_proyecto"].str.replace(u"Á", "A")
df["nombre_del_proyecto"] = df["nombre_del_proyecto"].str.replace(u"É", "E")
df["nombre_del_proyecto"] = df["nombre_del_proyecto"].str.replace(u"Í", "I")
df["nombre_del_proyecto"] = df["nombre_del_proyecto"].str.replace(u"Ó", "O")
df["nombre_del_proyecto"] = df["nombre_del_proyecto"].str.replace(u"Ú", "U")

# %%
df["donatario"] = df["donatario"].str.replace(u"Á", "A")
df["donatario"] = df["donatario"].str.replace(u"É", "E")
df["donatario"] = df["donatario"].str.replace(u"Í", "I")
df["donatario"] = df["donatario"].str.replace(u"Ó", "O")
df["donatario"] = df["donatario"].str.replace(u"Ú", "U")

# %%
df["donante"] = df["donante"].str.replace(u"Á", "A")
df["donante"] = df["donante"].str.replace(u"É", "E")
df["donante"] = df["donante"].str.replace(u"Í", "I")
df["donante"] = df["donante"].str.replace(u"Ó", "O")
df["donante"] = df["donante"].str.replace(u"Ú", "U")

# %%
df
# Out:
#        codigo                                nombre_del_proyecto  \
# 0     4986651          INSERCION A LA EDUCACION TECNICA SUPERIOR
# 1     5280931  OPERACION DE PROGRAMAS TERAPEUTICOS RESIDENCIA...
# 2     5308541  OPERACION DE PROGRAMAS TERAPEUTICOS AMBULATORI...
# 3     4989901  DERECHO A LA EDUCACION PARA TODOS: MEJORAMIENT...
# 4     2094102  ATENCION TECNICA DIRECTA AL ADULTO MAYOR INSTI...
# 5     5307051  OPERACION DE PROGRAMAS TERAPEUTICOS AMBULATORI...
# 6     4983391          INSERCION A LA EDUCACION TECNICA SUPERIOR
# 7     4975841        PROGRAMAS PREVENCION A LA DESERCION ESCOLAR
# 8     4987881          INSERCION A LA EDUCACION TECNICA SUPERIOR
# 9     4987612          INSERCION A LA EDUCACION TECNICA SUPERIOR
# 10    5288751  OPERACION DE PROGRAMAS TERAPEUTICOS RESIDENCIA...
# 11    5283631  OPERACION DE PROGRAMAS TERAPEUTICOS RESIDENCIA...
# 12    5290761  OPERACION DE PROGRAMAS TERAPEUTICOS RESIDENCIA...
# ...

# %%
df["donatario"].unique()
# Out:
# array(['FUNDACION EDUCACIONAL SUMATE', 'FUNDACION (PARENTESIS)',
#        'NFUTENS DAA LAC IFOUNN DEADCUIOCNA ECDIOUCNAACLIO SNUAML SAUTMEATE',
#        'FUNDACION LAS ROSAS', 'MARIA AYUDA CORPORACION DE BENEFICENCIA',
#        'FUNDACION ROSTROS NUEVOS',
#        'FUNDACION DE BENEFICENCIA AYUDA Y ESPERANZA',
#        'ONG DE DESARROLLO CONSEJO EMPRESARIAL DE LA EDUCACION',
#        'COANIQUEM', 'CASA DE ACOGIDA LA ESPERANZA',
#        'FUNDACION HOGAR ESPERANZA',
#        'SOCIEDAD DE BENEFICENCIA LA JUVENTUD HOMSIENSE SIRIA.'],
#       dtype=object)

# %%
correccion=pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vSCudnZE2a59_KYOYEZoytgAlswoQtnwj_1H1nmhh41U6jHC9MM_9LE6SaMylYLiXHZ48sIH4gE0nOV/pub?gid=0&single=true&output=csv")

# %%
correccion
# Out:
#                                       donatario_prev     donatario_new
# 0  NFUTENS DAA LAC IFOUNN DEADCUIOCNA ECDIOUCNAAC...  FUNDACION SUMATE

# %%
to_replace = correccion.set_index('donatario_prev')['donatario_new'].to_dict()
df['donatario'].replace(to_replace, inplace=True)

# %%
df.drop(columns=["año", 'mes', "dia"])
# Out:
#        codigo                                nombre_del_proyecto  \
# 0     4986651          INSERCION A LA EDUCACION TECNICA SUPERIOR
# 1     5280931  OPERACION DE PROGRAMAS TERAPEUTICOS RESIDENCIA...
# 2     5308541  OPERACION DE PROGRAMAS TERAPEUTICOS AMBULATORI...
# 3     4989901  DERECHO A LA EDUCACION PARA TODOS: MEJORAMIENT...
# 4     2094102  ATENCION TECNICA DIRECTA AL ADULTO MAYOR INSTI...
# 5     5307051  OPERACION DE PROGRAMAS TERAPEUTICOS AMBULATORI...
# 6     4983391          INSERCION A LA EDUCACION TECNICA SUPERIOR
# 7     4975841        PROGRAMAS PREVENCION A LA DESERCION ESCOLAR
# 8     4987881          INSERCION A LA EDUCACION TECNICA SUPERIOR
# 9     4987612          INSERCION A LA EDUCACION TECNICA SUPERIOR
# 10    5288751  OPERACION DE PROGRAMAS TERAPEUTICOS RESIDENCIA...
# 11    5283631  OPERACION DE PROGRAMAS TERAPEUTICOS RESIDENCIA...
# 12    5290761  OPERACION DE PROGRAMAS TERAPEUTICOS RESIDENCIA...
# ...
